# %% [markdown]
# #### Prerequisite

# %%
#Load SQL module

# %load_ext sql

# %%
#Connect to the database

# %sql mysql://root:****@localhost:3306/mydatadb
# Out:
# 'Connected: root@mydatadb'

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Select data and take a look of the dataset

# %%
# %%sql
#
# SELECT *
# FROM covid_deaths
# LIMIT 5;
# Out:
#  * mysql://root:***@localhost:3306/mydatadb
# 5 rows affected.
# [('AFG', 'Asia', 'Afghanistan', datetime.datetime(2020, 2, 24, 0, 0), 1.0, 1.0, None, None, None, None, 0.026, 0.026, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 8.33, 38928341.0, 54.422, 18.6, 2.581, 1.337, 1803.987, None, 597.029, 9.59, None, None, 37.746, 0.5, 64.83, 0.511),
#  ('AFG', 'Asia', 'Afghanistan', datetime.datetime(2020, 2, 25, 0, 0), 1.0, 0.0, None, None, None, None, 0.026, 0.0, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 8.33, 38928341.0, 54.422, 18.6, 2.581, 1.337, 1803.987, None, 597.029, 9.59, None, None, 37.746, 0.5, 64.83, 0.511),
# ...

# %% [markdown]
# As we can see, We have tons of data and many columns. We are not gonna work on all of them but few. Lets select toal_cases, new_cases, total_deaths and poplution.

# %%
# %%sql
#
# SELECT location, date, total_cases, new_cases, total_deaths, population
# FROM covid_deaths
# ORDER BY 2
# LIMIT 100;
# Out:
#  * mysql://root:***@localhost:3306/mydatadb
# 100 rows affected.
# [('Mexico', datetime.datetime(2020, 1, 1, 0, 0), None, None, None, 128932753.0),
#  ('Argentina', datetime.datetime(2020, 1, 1, 0, 0), None, None, None, 45195777.0),
#  ('Argentina', datetime.datetime(2020, 1, 2, 0, 0), None, None, None, 45195777.0),
#  ('Mexico', datetime.datetime(2020, 1, 2, 0, 0), None, None, None, 128932753.0),
#  ('Mexico', datetime.datetime(2020, 1, 3, 0, 0), None, None, None, 128932753.0),
#  ('Argentina', datetime.datetime(2020, 1, 3, 0, 0), None, None, None, 45195777.0),
#  ('Argentina', datetime.datetime(2020, 1, 4, 0, 0), None, None, None, 45195777.0),
#  ('Mexico', datetime.datetime(2020, 1, 4, 0, 0), None, None, None, 128932753.0),
#  ('Thailand', datetime.datetime(2020, 1, 4, 0, 0), None, None, None, 69799978.0),
#  ('Thailand', datetime.datetime(2020, 1, 5, 0, 0), None, None, None, 69799978.0),
#  ('Argentina', datetime.datetime(2020, 1, 5, 0, 0), None, None, None, 45195777.0),
# ...

# %% [markdown]
# BY running the query above we can clearly see that the first ever infected cases and deaths were spoted in china on January 22, 2020. Total death counted that day is 17 and total cases were 548.

# %% [markdown]
# Lets find out the overall death ratio compared to total cases from my home country which is Bangladesh.

# %%
# %%sql
#
# -- Total Cases vs Total Deaths
#
# SELECT location, date, total_cases, total_deaths, (total_deaths/total_cases)*100 AS Death_percentage
# FROM covid_deaths
# WHERE location like '%desh%' and continent is not null
# ORDER BY 5 DESC, 2
# LIMIT 100;
# Out:
#  * mysql://root:***@localhost:3306/mydatadb
# 100 rows affected.
# [('Bangladesh', datetime.datetime(2020, 3, 25, 0, 0), 39.0, 5.0, 12.82051282051282),
#  ('Bangladesh', datetime.datetime(2020, 4, 4, 0, 0), 70.0, 8.0, 11.428571428571429),
#  ('Bangladesh', datetime.datetime(2020, 3, 26, 0, 0), 44.0, 5.0, 11.363636363636363),
#  ('Bangladesh', datetime.datetime(2020, 4, 1, 0, 0), 54.0, 6.0, 11.11111111111111),
#  ('Bangladesh', datetime.datetime(2020, 4, 2, 0, 0), 56.0, 6.0, 10.714285714285714),
#  ('Bangladesh', datetime.datetime(2020, 3, 27, 0, 0), 48.0, 5.0, 10.416666666666668),
#  ('Bangladesh', datetime.datetime(2020, 3, 28, 0, 0), 48.0, 5.0, 10.416666666666668),
#  ('Bangladesh', datetime.datetime(2020, 3, 29, 0, 0), 48.0, 5.0, 10.416666666666668),
#  ('Bangladesh', datetime.datetime(2020, 4, 7, 0, 0), 164.0, 17.0, 10.365853658536585),
#  ('Bangladesh', datetime.datetime(2020, 3, 24, 0, 0), 39.0, 4.0, 10.256410256410255),
# ...
